# %%
import pandas
import matplotlib.pyplot as plt
import numpy

# %%
data = pandas.read_csv(r'data\VDC_Syria_CASREP.csv', encoding = "ISO-8859-1")
data.drop(['province', 'birthPlace'], axis=1, inplace=True)

# %%
count = 0
for x in range(0, 210213):
    current_selection = str(data['gender'][x])
    if ('Female' in current_selection):
        count = count + 1

# %%
count
# Out:
# 25412

# %%
data
# Out:
#                                         name        status          gender  \
# 0                          Abd al-Aziz Aswad      Civilian    Adult - Male
# 1           Mohammad Saheeb Abdullah Mansour  Non-Civilian    Adult - Male
# 2                 Doshaish Hosain Hasan Hamo  Non-Civilian    Adult - Male
# 3                            Ammar al-Jawhar  Non-Civilian    Adult - Male
# 4                          Adeeb Rida Bakour  Non-Civilian    Adult - Male
# 5             Mahmoud al-Abdullah |al-Dames"  Non-Civilian    Adult - Male
# 6                      Daleh Mohammad al-Eid      Civilian  Adult - Female
# 7                  Khadijeh Ismaeil al-Doush      Civilian  Adult - Female
# 8                               Unidentified  Non-Civilian    Adult - Male
# 9                        Khattab Abu Ibrahim  Non-Civilian    Adult - Male
# 10                  Yousef Abdulla al-Halabi      Civilian    Adult - Male
# ...
