# %%
import pandas
import numpy as np
import plotly
import matplotlib.pyplot as plt

# %%
def clean_data(x):
    x = x.replace(',', '')
    return x

# %%
data_a = pandas.read_csv('Data/PLHIV.csv')

# %%
data_a = data_.applymap(clean_data)
data_a = data_.set_index('State/UT')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Users\Yatharth\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State/UT'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-fd00b7daea19> in <module>()
# ...

# %%
data_a.columns
# Out:
# Index(['Lower 2007', 'Estimate 2007', 'Upper 2007', 'Lower 2008',
#        'Estimate 2008', 'Upper 2008', 'Lower 2009', 'Estimate 2009',
#        'Upper 2009', 'Lower 2010', 'Estimate 2010', 'Upper 2010', 'Lower 2011',
#        'Estimate 2011', 'Upper 2011'],
#       dtype='object')

# %%
data_a
# Out:
#                           Lower 2007 Estimate 2007 Upper 2007 Lower 2008  \
# State/UT
# Andhra Pradesh                431991        489063     551360     413656
# Arunachal Pradesh                135           458       1292        175
# Assam                           4159          6225       9658       4958
# Bihar                          95205        122770     157352      95857
# Chhattisgarh                   21581         30124      44184      24018
# Delhi                           7530         17656      30577       8603
# Goa                             2488          5312      14700       2322
# Gujarat                       113285        137468     165179     109355
# Himachal Pradesh                4355          6113       9330       4590
# Haryana                         8269         14788      22235       9363
# Jharkhand                      16929         23775      33000      19988
# Jammu & Kashmir                 1142          2433       4284       1344
# ...

# %%
data_b = pandas.read_csv('Data/New_Infections_Adult.csv')
data_b = data_.applymap(clean_data)

# %%
data_b
# Out:
#                           Lower 2007 Estimate 2007 Upper 2007 Lower 2008  \
# State/UT
# Andhra Pradesh                431991        489063     551360     413656
# Arunachal Pradesh                135           458       1292        175
# Assam                           4159          6225       9658       4958
# Bihar                          95205        122770     157352      95857
# Chhattisgarh                   21581         30124      44184      24018
# Delhi                           7530         17656      30577       8603
# Goa                             2488          5312      14700       2322
# Gujarat                       113285        137468     165179     109355
# Himachal Pradesh                4355          6113       9330       4590
# Haryana                         8269         14788      22235       9363
# Jharkhand                      16929         23775      33000      19988
# Jammu & Kashmir                 1142          2433       4284       1344
# ...

# %%
data_c = pandas.read_csv('Data/New_Infections_Adult.csv')

# %%
data_c
# Out:
#                      State/UT Lower 2007 Estimate 2007 Upper 2007 Lower 2008  \
# 0              Andhra Pradesh     12,209        22,063     33,510      8,899
# 1           Arunachal Pradesh         13           104        304         19
# 2                       Assam        566         1,219      1,899        486
# 3                       Bihar      6,104         9,688     17,842      5,688
# 4                Chhattisgarh      1,384         4,130      7,983      1,478
# 5                       Delhi        685         1,902      4,512        644
# 6                         Goa         15           180      1,010         13
# 7                     Gujarat      4,444         7,677     12,146      4,083
# 8            Himachal Pradesh        387           675      1,771        325
# 9                     Haryana        931         1,664      4,105        862
# 10                  Jharkhand      3,139         4,621      6,721      3,553
# ...
